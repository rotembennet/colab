# %% [markdown]
# <a href="https://colab.research.google.com/github/rotembennet/colab/blob/main/notebooks/Course1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('whatever')
# Out:
# whatever

# %% [markdown]
# # New Section
# **bold text**
#
# *italicized text*
#
# [link text](https://)
# bla

# %% [markdown]
# $m=a^2$

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 264 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 57 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 93 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 42.1 MB/s
# ...
#      |████████████████████████████████| 254 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 33.7 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.5 MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11958 sha256=b744c5049034f280f8235791fde7beb6b3e320932c9010859570199366c1b7ea
#   Stored in directory: /root/.cache/pip/wheels/c9/d6/6a/de198d890277cde60ca3dbebe7ae592d3b381c7d9bb2455f4d
# Successfully built PyDispatcher
# ...

# %%
import scrapy

# %%
# !pip uninstall scrapy
# Out:
# Found existing installation: Scrapy 2.6.3
# Uninstalling Scrapy-2.6.3:
#   Would remove:
#     /usr/local/bin/scrapy
#     /usr/local/lib/python3.7/dist-packages/Scrapy-2.6.3.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/scrapy/*
# Proceed (y/n)? y
#   Successfully uninstalled Scrapy-2.6.3

# %%
# !apt-get install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.

# %%
# !pip freeze
# Out:
# absl-py==1.2.0
# aeppl==0.0.33
# aesara==2.7.9
# aiohttp==3.8.3
# aiosignal==1.2.0
# alabaster==0.7.12
# albumentations==1.2.1
# altair==4.2.0
# appdirs==1.4.4
# arviz==0.12.1
# astor==0.8.1
# astropy==4.3.1
# astunparse==1.6.3
# async-timeout==4.0.2
# asynctest==0.13.0
# atari-py==0.2.9
# atomicwrites==1.4.1
# attrs==22.1.0
# audioread==3.0.0
# autograd==1.5
# Automat==20.2.0
# Babel==2.10.3
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==5.0.1
# blis==0.7.8
# bokeh==2.3.3
# branca==0.5.0
# bs4==0.0.1
# CacheControl==0.12.11
# cached-property==1.5.2
# cachetools==4.2.4
# catalogue==2.0.8
# certifi==2022.9.24
# cffi==1.15.1
# cftime==1.6.2
# chardet==3.0.4
# charset-normalizer==2.1.1
# click==7.1.2
# clikit==0.6.2
# cloudpickle==1.5.0
# cmake==3.22.6
# cmdstanpy==1.0.7
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.0.2
# cons==0.4.5
# constantly==15.1.0
# contextlib2==0.5.5
# convertdate==2.4.0
# crashtest==0.3.1
# crcmod==1.7
# cryptography==38.0.1
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/My Drive/colab.txt', 'w') as f:
    f.write('test text')

# %%
with open('/content/gdrive/My Drive/colab.txt', 'r') as f:
    print(f.read())
# Out:
# test text

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
    print(uploaded[filename])
# Out:
#      <input type="file" id="files-5f9d7ab4-1961-457f-97fe-a2525f102959" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f9d7ab4-1961-457f-97fe-a2525f102959">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open('colab.txt', 'w') as f:
    f.write('Hi Hi')

files.download('colab.txt')

# %%
# !wget 25.io/toau/audio/sample.txt
# Out:
# --2022-10-12 20:50:06--  http://25.io/toau/audio/sample.txt
# Resolving 25.io (25.io)... 192.169.145.195
# Connecting to 25.io (25.io)|192.169.145.195|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-10-12 20:50:06 ERROR 404: Not Found.
